# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
# data.yaml path: "C:\Users\rlati\workspace\smokedataset\Smoking_detection1.v17i.yolov8\data.yaml"
# train dataset path: C:\Users\rlati\workspace\smokedataset\Smoking_detection1.v17i.yolov8\train
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 25.1MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 3.88MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 89.5ms
# Speed: 13.1ms preprocess, 89.5ms inference, 3328.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8x-cls.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 110M/110M [00:02<00:00, 55.8MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-cls summary (fused): 133 layers, 57404200 parameters, 0 gradients, 154.8 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# ...
# 100% 755k/755k [00:00<00:00, 5.05MB/s]
# image 1/1 /content/bus.jpg: 224x224 minibus 0.89, police_van 0.06, school_bus 0.03, trolleybus 0.01, streetcar 0.01, 14.1ms
# Speed: 51.9ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8x.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 131M/131M [00:01<00:00, 71.3MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 102.3ms
# Speed: 3.5ms preprocess, 102.3ms inference, 1954.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !unzip Smoking_detection1.v17i.yolov8.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b588_jpg.rf.446dbb6e09055de9a354a5f9b65af99e.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b589_jpg.rf.173ecb8fe9acc05c7032c60f0bfd40d3.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b591_jpg.rf.d2ab1eaab65d85dfa9d95015faa73f4b.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b597_jpg.rf.f489807a01bd6f67d0979a52863deaa7.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b598_jpg.rf.f3dc899d308ea4e0cf79cfeeb330a686.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b600_jpg.rf.cd6642dd3370a3984d8129d43c865117.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b605_jpg.rf.0175352c5bc42708a8509de70358ed92.txt
#   inflating: Smoking_detection1.v17i.yolov8/train/labels/smoke_b611_jpg.rf.db51e09db12da104f7cade59a99b3e29.txt
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
#from ultralytics import YOLO

# Load the model.
model = YOLO('yolov8n.pt')

# Training.
results = model.train(
   data="/content/Smoking_detection1.v17i.yolov8/data.yaml",
   imgsz=640,
   epochs=20,
   batch=16,
   optimizer='SGD',
   seed=42,
   dropout=0.3,
   name='yolov8n_custom'
)
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !zip -r /content/runs/detect/yolov8n_custom2
# Out:
# zip error: Nothing to do! (/content/runs/detect/yolov8n_custom2.zip)
